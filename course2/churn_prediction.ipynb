# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 3.1 Machine Learning for Classification problems

# %%
df = pd.read_csv("data/churn_data/churndata.csv")

# %% [markdown]
# ## 3.2 Data cleaning

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='str')

# %%
df.totalcharges = df.totalcharges.str.replace(" ", "")

# %%
df.totalcharges = pd.to_numeric(df.totalcharges)

# %%
df.dtypes
# Out:
# customerid              str
# gender                  str
# seniorcitizen         int64
# partner                 str
# dependents              str
# tenure                int64
# phoneservice            str
# multiplelines           str
# internetservice         str
# onlinesecurity          str
# onlinebackup            str
# deviceprotection        str
# techsupport             str
# streamingtv             str
# streamingmovies         str
# contract                str
# paperlessbilling        str
# paymentmethod           str
# monthlycharges      float64
# totalcharges        float64
# churn                   str
# dtype: object

# %%
#normalizing str column data

str_col = df.dtypes[df.dtypes == "str"].index

# %%
str_col
# Out:
# Index(['customerid', 'gender', 'partner', 'dependents', 'phoneservice',
#        'multiplelines', 'internetservice', 'onlinesecurity', 'onlinebackup',
#        'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies',
#        'contract', 'paperlessbilling', 'paymentmethod', 'churn'],
#       dtype='str')

# %%
for col in str_col:
    df[col] = df[col].str.lower().str.replace(" ", "_")

# %%
df.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-vhveg  female              0     yes         no       1           no
# 1  5575-gnvde    male              0      no         no      34          yes
# 2  3668-qpybk    male              0      no         no       2          yes
# 3  7795-cfocw    male              0      no         no      45           no
# 4  9237-hqitu  female              0      no         no       2          yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  no_phone_service             dsl             no  ...               no
# 1                no             dsl            yes  ...              yes
# 2                no             dsl            yes  ...               no
# 3  no_phone_service             dsl            yes  ...              yes
# 4                no     fiber_optic             no  ...               no
#
# ...

# %%
df.churn = (df.churn == "yes").astype(int)

# %%
df.churn
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: churn, Length: 7043, dtype: int64

# %% [markdown]
# ## 3.3 Setting up validation framework

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train = df

# %%
df_full_train.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-vhveg  female              0     yes         no       1           no
# 1  5575-gnvde    male              0      no         no      34          yes
# 2  3668-qpybk    male              0      no         no       2          yes
# 3  7795-cfocw    male              0      no         no      45           no
# 4  9237-hqitu  female              0      no         no       2          yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  no_phone_service             dsl             no  ...               no
# 1                no             dsl            yes  ...              yes
# 2                no             dsl            yes  ...               no
# 3  no_phone_service             dsl            yes  ...              yes
# 4                no     fiber_optic             no  ...               no
#
# ...

# %%
df_train, df_test = train_test_split(df_full_train, test_size=0.4, random_state=1)

# %%
df_train.shape, df_test.shape
# Out:
# ((4225, 21), (2818, 21))

# %%
df_test, df_val = train_test_split(df_test, test_size=0.5, random_state=1)

# %%
df_test.shape, df_val.shape
# Out:
# ((1409, 21), (1409, 21))

# %%
df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)

# %%
y_train.shape, y_val.shape, y_test.shape
# Out:
# ((4225,), (1409,), (1409,))

# %%
y_train = df_train.churn.values
y_test = df_test.churn.values
y_val = df_val.churn.values

# %%
del df_train["churn"]
del df_test["churn"]
del df_val["churn"]

# %%
df_test.shape
# Out:
# (1409, 20)

# %%
df_full_train.isnull().sum()
# Out:
# customerid           0
# gender               0
# seniorcitizen        0
# partner              0
# dependents           0
# tenure               0
# phoneservice         0
# multiplelines        0
# internetservice      0
# onlinesecurity       0
# onlinebackup         0
# deviceprotection     0
# techsupport          0
# streamingtv          0
# streamingmovies      0
# contract             0
# paperlessbilling     0
# paymentmethod        0
# monthlycharges       0
# totalcharges        11
# churn                0
# dtype: int64

# %%
df_train = df_train.fillna(0)
df_test = df_test.fillna(0)
df_val = df_val.fillna(0)

# %%
df_val.isnull().sum()
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# dtype: int64

# %% [markdown]
# ## 3.4 EDA

# %%
df_full_train.churn.value_counts(normalize=True)
# Out:
# churn
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64

# %%
df_full_train.dtypes
# Out:
# customerid              str
# gender                  str
# seniorcitizen         int64
# partner                 str
# dependents              str
# tenure                int64
# phoneservice            str
# multiplelines           str
# internetservice         str
# onlinesecurity          str
# onlinebackup            str
# deviceprotection        str
# techsupport             str
# streamingtv             str
# streamingmovies         str
# contract                str
# paperlessbilling        str
# paymentmethod           str
# monthlycharges      float64
# totalcharges        float64
# churn                 int64
# dtype: object

# %%
numerical_column = ["tenure", "monthlycharges", "totalcharges"]

# %%
categorical = [
    'gender',
    'seniorcitizen',
    'partner',
    'dependents',
    'phoneservice',
    'multiplelines',
    'internetservice',
    'onlinesecurity',
    'onlinebackup',
    'deviceprotection',
    'techsupport',
    'streamingtv',
    'streamingmovies',
    'contract',
    'paperlessbilling',
    'paymentmethod',
]

# %%
df_full_train[categorical].nunique()
# Out:
# gender              2
# seniorcitizen       2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# dtype: int64

# %% [markdown]
# ## 3.5 Feature Importance: Churn Rate and Risk Ratio

# %%
df_full_train.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-vhveg  female              0     yes         no       1           no
# 1  5575-gnvde    male              0      no         no      34          yes
# 2  3668-qpybk    male              0      no         no       2          yes
# 3  7795-cfocw    male              0      no         no      45           no
# 4  9237-hqitu  female              0      no         no       2          yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  no_phone_service             dsl             no  ...               no
# 1                no             dsl            yes  ...              yes
# 2                no             dsl            yes  ...               no
# 3  no_phone_service             dsl            yes  ...              yes
# 4                no     fiber_optic             no  ...               no
#
# ...

# %%
churn_female = df_full_train[(df_full_train.gender == "female")].churn.mean()
churn_female
# Out:
# np.float64(0.26920871559633025)

# %%
churn_male = df_full_train[(df_full_train.gender == "male")].churn.mean()
churn_male
# Out:
# np.float64(0.2616033755274262)

# %%
global_churn_rate = df_full_train.churn.mean()
global_churn_rate
# Out:
# np.float64(0.2653698707936959)

# %%
df_full_train.partner.value_counts()
# Out:
# partner
# no     3641
# yes    3402
# Name: count, dtype: int64

# %%
churn_yes_partner = df_full_train[df_full_train.partner == "yes"].churn.mean()
churn_yes_partner
# Out:
# np.float64(0.1966490299823633)

# %%
churn_no_partner = df_full_train[df_full_train.partner == "no"].churn.mean()
churn_no_partner
# Out:
# np.float64(0.32957978577313923)

# %%
global_churn_rate - churn_no_partner
# Out:
# np.float64(-0.06420991497944334)

# %%
global_churn_rate - churn_yes_partner
# Out:
# np.float64(0.06872084081133259)

# %% [markdown]
# ### Risk Ratio

# %%
churn_no_partner/global_churn_rate
# Out:
# np.float64(1.241963847619165)

# %%
churn_yes_partner/global_churn_rate
# Out:
# np.float64(0.7410375164075894)

# %%
from IPython.display import display

# %%
for c in categorical:
    df_group = df_full_train.groupby(c).churn.agg(["mean", "count"])
    df_group["diff"] = df_group["mean"] - global_churn_rate
    df_group["risk/raito"] = df_group["mean"] / global_churn_rate
    display(df_group)
    print()
# Out:
#             mean  count      diff  risk/raito
# gender
# female  0.269209   3488  0.003839    1.014466
# male    0.261603   3555 -0.003766    0.985807
#                    mean  count      diff  risk/raito
# seniorcitizen
# 0              0.236062   5901 -0.029308    0.889557
# 1              0.416813   1142  0.151443    1.570686
#              mean  count      diff  risk/raito
# partner
# no       0.329580   3641  0.064210    1.241964
# yes      0.196649   3402 -0.068721    0.741038
#                 mean  count      diff  risk/raito
# dependents
# no          0.312791   4933  0.047422    1.178700
# yes         0.154502   2110 -0.110868    0.582215
#                   mean  count      diff  risk/raito
# phoneservice
# no            0.249267    682 -0.016103    0.939319
# yes           0.267096   6361  0.001726    1.006506
#                       mean  count      diff  risk/raito
# multiplelines
# no                0.250442   3390 -0.014927    0.943749
# ...
