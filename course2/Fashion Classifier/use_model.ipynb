# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.applications.xception import decode_predictions

from tensorflow.keras.preprocessing.image import load_img

# %%
model = keras.models.load_model("xception_v5_15_0.800.h5")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
img_path = "./data/images/0fc3fbae-1ce6-47c3-b183-0d12bf11914f.jpg"

# %%
img = load_img(img_path, target_size= (299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
x = np.array([img])
x = preprocess_input(x)

# %%
pred = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step

# %%
decode_predictions(pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 decode_predictions(pred)
#
# File ~\.virtualenvs\Fashion_Classifier-6oIB2VQW\Lib\site-packages\keras\src\applications\xception.py:347, in decode_predictions(preds, top)
#     345 @keras_export("keras.applications.xception.decode_predictions")
#     346 def decode_predictions(preds, top=5):
# --> 347     return imagenet_utils.decode_predictions(preds, top=top)
#
# File ~\.virtualenvs\Fashion_Classifier-6oIB2VQW\Lib\site-packages\keras\src\applications\imagenet_utils.py:136, in decode_predictions(preds, top)
#     133 global CLASS_INDEX
#     135 if len(preds.shape) != 2 or preds.shape[1] != 1000:
# --> 136     raise ValueError(
#     137         "`decode_predictions` expects "
#     138         "a batch of predictions "
#     139         "(i.e. a 2D array of shape (samples, 1000)). "
#     140         f"Received array with shape: {preds.shape}"
#     141     )
#     142 if CLASS_INDEX is None:
#     143     fpath = file_utils.get_file(
#     144         "imagenet_class_index.json",
#     145         CLASS_INDEX_PATH,
#     146         cache_subdir="models",
#     147         file_hash="c2c37ea517e94d9795004a39431a14cb",
#     148     )
#
# ValueError: `decode_predictions` expects a batch of predictions (i.e. a 2D array of shape (samples, 1000)). Received array with shape: (1, 18)

# %%
type(pred)
# Out:
# numpy.ndarray

# %%
classes = ['blazer',
 'blouse',
 'body',
 'dress',
 'hat',
 'hoodie',
 'longsleeve',
 'other',
 'outwear',
 'pants',
 'polo',
 'shirt',
 'shoes',
 'shorts',
 'skirt',
 't-shirt',
 'top',
 'undershirt']

# %%
probabilites = tf.nn.softmax(pred)[0]

# %%
predicted_index = np.argmax(probabilities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 predicted_index = np.argmax(probabilities)
#
# NameError: name 'probabilities' is not defined
